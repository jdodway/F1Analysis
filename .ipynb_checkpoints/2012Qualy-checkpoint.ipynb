# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
url = 'https://raw.githubusercontent.com/jdodway/F1Analysis/main/F1QueryResults/F1Qual2012.csv'
df = pd.read_csv(url)
df['Constructor']=df['name.1']
df.drop('name.1',axis=1,inplace=True)
df.replace(r'\N',np.nan,inplace=True) 
df['fullname']=df['forename']+' '+df['surname']
df.drop('surname',axis=1,inplace=True)
df.drop('forename',axis=1,inplace=True)
df
# Out:
#      raceId  year                   name        q3  position Constructor  \
# 0       860  2012  Australian Grand Prix  1:24.922         1     McLaren
# 1       860  2012  Australian Grand Prix  1:25.074         2     McLaren
# 2       860  2012  Australian Grand Prix  1:25.302         3    Lotus F1
# 3       860  2012  Australian Grand Prix  1:25.336         4    Mercedes
# 4       860  2012  Australian Grand Prix  1:25.651         5    Red Bull
# ..      ...   ...                    ...       ...       ...         ...
# 471     879  2012   Brazilian Grand Prix       NaN        20    Caterham
# 472     879  2012   Brazilian Grand Prix       NaN        21    Marussia
# 473     879  2012   Brazilian Grand Prix       NaN        22    Marussia
# 474     879  2012   Brazilian Grand Prix       NaN        23         HRT
# 475     879  2012   Brazilian Grand Prix       NaN        24         HRT
#
#                fullname
# 0        Lewis Hamilton
# 1         Jenson Button
# ...

# %%
drivers={}
for index,row in df.iterrows():
    if any(row['fullname']) in drivers==True:
        print('Driver in dict already')
    else: 
        fullname=row['fullname']
        drivers[fullname]=row['Constructor']

# %%
del drivers["Jerome d'Ambrosio"]

# %%
del drivers["Narain Karthikeyan"]
del drivers["Pedro de la Rosa"]

# %%
drivers
# Out:
# {'Lewis Hamilton': 'McLaren',
#  'Jenson Button': 'McLaren',
#  'Romain Grosjean': 'Lotus F1',
#  'Michael Schumacher': 'Mercedes',
#  'Mark Webber': 'Red Bull',
#  'Sebastian Vettel': 'Red Bull',
#  'Nico Rosberg': 'Mercedes',
#  'Pastor Maldonado': 'Williams',
#  'Nico Hulkenberg': 'Force India',
#  'Daniel Ricciardo': 'Toro Rosso',
#  'Jean-eric Vergne': 'Toro Rosso',
#  'Fernando Alonso': 'Ferrari',
#  'Kamui Kobayashi': 'Sauber',
#  'Bruno Senna': 'Williams',
#  'Paul di Resta': 'Force India',
#  'Felipe Massa': 'Ferrari',
#  'Sergio Perez': 'Sauber',
#  'Kimi Raikkonen': 'Lotus F1',
#  'Heikki Kovalainen': 'Caterham',
#  'Vitaly Petrov': 'Caterham',
#  'Timo Glock': 'Marussia',
#  'Charles Pic': 'Marussia'}

# %%
tracks=df['name'].unique().tolist()
tracks
# Out:
# ['Australian Grand Prix',
#  'Malaysian Grand Prix',
#  'Chinese Grand Prix',
#  'Bahrain Grand Prix',
#  'Spanish Grand Prix',
#  'Monaco Grand Prix',
#  'Canadian Grand Prix',
#  'European Grand Prix',
#  'British Grand Prix',
#  'German Grand Prix',
#  'Hungarian Grand Prix',
#  'Belgian Grand Prix',
#  'Italian Grand Prix',
#  'Singapore Grand Prix',
#  'Japanese Grand Prix',
#  'Korean Grand Prix',
#  'Indian Grand Prix',
#  'Abu Dhabi Grand Prix',
#  'United States Grand Prix',
#  'Brazilian Grand Prix']

# %%
qual =df.groupby(['name','Constructor','fullname','position']).sum()
qual.drop(['raceId','year'],axis=1,inplace=True)
for track in tracks:
    for index,row in qual.iterrows():
# Out:
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Abu Dhabi Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# Australian Grand Prix
# ...

# %%
len(qual)/len(drivers)
# Out:
# 21.636363636363637

# %%
for track in tracks:
    for index,row in df.iterrows():
